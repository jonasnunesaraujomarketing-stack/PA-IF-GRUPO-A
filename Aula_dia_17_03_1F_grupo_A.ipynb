# %% [markdown]
# <a href="https://colab.research.google.com/github/jonasnunesaraujomarketing-stack/PA-IF-GRUPO-A/blob/main/Aula_dia_17_03_1F_grupo_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

soma = a + b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
print("----------------------------SOMA--------------------------------------")
print("")
print (f"O resultado da Soma de {a} MAIS {b} é igual a : {soma}")
print("")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 5
# digite um numero: 6
#
# ------------------------OPERADORES ARITIMÉTICOS-----------------------
#
# ----------------------------SOMA--------------------------------------
#
# O resultado da Soma de 5 MAIS 6 é igual a : 11
#
# ----------------------------------------------------------------------

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

subtracao = a - b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
print("----------------------------SUBTRACAO--------------------------------------")
print("")
print (f"O resultado da subtração de {a} MAIS {b} é igual a : {subtracao}")
print("")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 5
# digite um numero: 3
#
# ------------------------OPERADORES ARITIMÉTICOS-----------------------
#
# ----------------------------SUBTRACAO--------------------------------------
#
# O resultado da subtração de 5 MAIS 3 é igual a : 2
#
# ----------------------------------------------------------------------

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

divisão = a / b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
print("----------------------------DIVISÃO--------------------------------------")
print("")
print (f"O resultado da divisão de {a} MAIS {b} é igual a : {divisão}")
print("")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 10
# digite um numero: 5
#
# ------------------------OPERADORES ARITIMÉTICOS-----------------------
#
# ----------------------------DIVISÃO--------------------------------------
#
# O resultado da divisão de 10 MAIS 5 é igual a : 2.0
#
# ----------------------------------------------------------------------

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

multiplicação = a * b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
print("----------------------------MULTIPLICACÃO--------------------------------------")
print("")
print (f"O resultado da muitiplicação de {a} MAIS {b} é igual a : {multiplicação}")
print("")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 5
# digite um numero: 10
#
# ------------------------OPERADORES ARITIMÉTICOS-----------------------
#
# ----------------------------MULTIPLICAÇÃO--------------------------------------
#
# O resultado da muitiplicação de 5 MAIS 10 é igual a : 50
#
# ----------------------------------------------------------------------

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

soma = a + b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

soma = a + b

# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS-----------------------")
print("")
print("----------------------------SOMA--------------------------------------")
print("")
print (f"O resultado da Soma de {a} MAIS {b} é igual a : {soma}")
print("")
print("----------------------------------------------------------------------")

print("----------------------------------------------------------------------")

# %%
# Operadores aritiméticos
# Fazer um programa que calcula operações com 02 numeros


# Entrada

a = int (input("digite um numero: "))
b = int (input("digite um numero: "))


# Processamento

soma = a + b
subtração = a - b
divisão = a / b
multiplicação = a * b
div_int =


# Saida
print ("")
print("------------------------OPERADORES ARITIMÉTICOS------------------------")
print("")
print("----------------------------SOMA---------------------------------------")
print("")
print (f"O resultado da Soma de {a} MAIS {b} é igual a : {soma}")
print("")
print("---------------------------SUBTRAÇÃO-----------------------------------")
print("")
print (f"O resultado da subtração de {a} MAIS {b} é igual a : {subtração}")
print("")
print("------------------------MULTIPLICAÇÃO----------------------------------")
print("")
print (f"O resultado da multiplicação de {a} MAIS {b} é igual a : {multiplicação}")
print("")
print("---------------------------DIVISÃO-----------------------------------")
print("")
print (f"O resultado da divisão de {a} MAIS {b} é igual a : {divisão}")
print("")
print("-------------------------DIVISÃO INTEIRA-------------------------------")
print("")
print (f"O resultado da divisão de {a} MAIS {b} é igual a : {div_int}")
print("")
# Out:
# digite um numero: 5
# digite um numero: 6
#
# ------------------------OPERADORES ARITIMÉTICOS------------------------
#
# ----------------------------SOMA---------------------------------------
#
# O resultado da Soma de 5 MAIS 6 é igual a : 11
#
# ----------------------------DIVISÃO------------------------------------
#
# O resultado da divisão de 5 MAIS 6 é igual a : 0.8333333333333334
#
# ------------------------MULTIPLICAÇÃO----------------------------------
#
# O resultado da multiplicação de 5 MAIS 6 é igual a : 30
#
# ---------------------------SUBTRAÇÃO-----------------------------------
#
# O resultado da subtração de 5 MAIS 6 é igual a : -1

# %%
# Operadores relacionais

# Entrada

a = int (input("digite um numero"))
b = int (input("digite um numero"))

# Processamento

# Comparação

igual = a == b

# saida

print (igual)
# Out:
# digite um numero5
# digite um numero6
# False

# %%
# Operadores relacionais

# Entrada

a = int (input("digite um numero"))
b = int (input("digite um numero"))

# Processamento

# Comparação

diferente = a != b

# Saida

print(diferente)
# Out:
# digite um numero5
# digite um numero6
# True

# %%
# Operadores relacionais

# Entrada

a = int (input("digite um numero"))
b = int (input("digite um numero"))

# Processamento

# Comparação

maior = a > b
menor = a < b
maiorigual = a >= b
menorigual = a <= b

# Saida

print (maior)
print("")
print("-----------------------------------------------------------------------")
print(menor)
print("-----------------------------------------------------------------------")
print(maiorigual)
print("-----------------------------------------------------------------------")
print(menorigual)
# Out:
# digite um numero5
# digite um numero6
# False
#
# ----------------------------------------------------------------------
# True
# -----------------------------------------------------------------------
# False
# -----------------------------------------------------------------------
# True

# %%
# Fazer um programa para converter a temperatura
# F= (C × 9/5) + 32

# Entrada

c = float (input("Digite um numero para ser convertido: "))

# Processamento

temperatura = (c * 9/5) + 32

# Saida

print (f" a tempera passou de {C} para {temperatura}")
# Out:
# Digite um numero para ser convertido: 100
#  a tempera passou de 5.9 para 212.0

# %%
# Fazer um programa que converte km em metros

# Entrada

a = float (input("Digite em km para ser convertido em metros: "))

# Processamento

metros = a * 1000

# Saida

print (f"O resultado de {a} em metros é: {metros}")
# Out:
# Digite em km para ser convertido em metros: 50000
# O resultado de 50000.0 em metros é: 50.0

# %%
# HRS EM MINUTOS

# Entrada

a = float (input("Digite o numero de horas para ser convertido em minutos: "))

# Processamento

minutos = a * 60

# saida

print (f"O resultado de {a} em minutos é: {minutos}")
# Out:
# Digite o numero de horas para ser convertido em minutos: 5
# O resultado de 5.0 em minutos é: 300.0
